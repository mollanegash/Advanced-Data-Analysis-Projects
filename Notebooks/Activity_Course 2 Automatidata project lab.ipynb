# %% [markdown]
# # **Automatidata project**
# **Course 2 - Get Started with Python**

# %% [markdown]
# Welcome to the Automatidata Project!
#
# You have just started as a data professional in a fictional data consulting firm, Automatidata. Their client, the New York City Taxi and Limousine Commission (New York City TLC), has hired the Automatidata team for its reputation in helping their clients develop data-based solutions.
#
# The team is still in the early stages of the project. Previously, you were asked to complete a project proposal by your supervisor, DeShawn Washington. You have received notice that your project proposal has been approved and that New York City TLC has given the Automatidata team access to their data. To get clear insights, New York TLC's data must be analyzed, key variables identified, and the dataset ensured it is ready for analysis.
#
# A notebook was structured and prepared to help you in this project. Please complete the following questions.

# %% [markdown]
# # Course 2 End-of-course project: Inspect and analyze data
#
# In this activity, you will examine data provided and prepare it for analysis.  This activity will help ensure the information is,
#
# 1.   Ready to answer questions and yield insights
#
# 2.   Ready for visualizations
#
# 3.   Ready for future hypothesis testing and statistical methods
# <br/>
#
# **The purpose** of this project is to investigate and understand the data provided.
#
# **The goal** is to use a dataframe contructed within Python, perform a cursory inspection of the provided dataset, and inform team members of your findings.
# <br/>
# *This activity has three parts:*
#
# **Part 1:** Understand the situation
# * Prepare to understand and organize the provided taxi cab dataset and information.
#
# **Part 2:** Understand the data
#
# * Create a pandas dataframe for data learning, future exploratory data analysis (EDA), and statistical activities.
#
# * Compile summary information about the data to inform next steps.
#
# **Part 3:** Understand the variables
#
# * Use insights from your examination of the summary data to guide deeper investigation into specific variables.
#
#
# <br/>
# Follow the instructions and answer the following questions to complete the activity. Then, you will complete an Executive Summary using the questions listed on the PACE Strategy Document.
#
# Be sure to complete this activity before moving on. The next course item will provide you with a completed exemplar to compare to your own work.

# %% [markdown]
# # **Identify data types and relevant variables using Python**

# %% [markdown]
# <img src="images/Pace.png" width="100" height="100" align=left>
#
# # **PACE stages**

# %% [markdown]
# Throughout these project notebooks, you'll see references to the problem-solving framework PACE. The following notebook components are labeled with the respective PACE stage: Plan, Analyze, Construct, and Execute.

# %% [markdown]
# <img src="images/Plan.png" width="100" height="100" align=left>
#
#
# ## PACE: **Plan**
#
# Consider the questions in your PACE Strategy Document and those below to craft your response:

# %% [markdown]
# ### **Task 1. Understand the situation**
#
# *   How can you best prepare to understand and organize the provided taxi cab information?

# %% [markdown]
# ==> ENTER YOUR RESPONSE HERE
# Prepare to understand and organize the provided taxi cab dataset and information.I prepare myslf by reading the given letter form the client and the given data.
# :use pands and data frame

# %% [markdown]
# <img src="images/Analyze.png" width="100" height="100" align=left>
#
# ## PACE: **Analyze**
#
# Consider the questions in your PACE Strategy Document to reflect on the Analyze stage.

# %% [markdown]
# ### **Task 2a. Build dataframe**

# %% [markdown]
# Create a pandas dataframe for data learning, and future exploratory data analysis (EDA) and statistical activities.
#
# **Code the following,**
#
# *   import pandas as `pd`. pandas is used for buidling dataframes.
#
# *   import numpy as `np`. numpy is imported with pandas
#
# *   `df = pd.read_csv('Datasets\NYC taxi data.csv')`
#
# **Note:** pair the data object name `df` with pandas functions to manipulate data, such as `df.groupby()`.
#
# **Note:** As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
#Import libraries and packages listed above
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset into dataframe
df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')
print("done")

# Set a clean style for plots
sns.set(style="whitegrid")
plt.figure(figsize=(10, 5))
sns.histplot(df['fare_amount'], bins=50, kde=True)
plt.title('Distribution of Fare Amount')
plt.xlabel('Fare Amount ($)')
plt.ylabel('Frequency')
plt.xlim(0, 100)  # limit to better visualize common values
plt.show()
# Out:
# done

# %% [markdown]
# ### **Task 2b. Understand the data - Inspect the data**
#
# View and inspect summary information about the dataframe by coding the following:
#
# 1. `df.head(10)`
# 2. `df.info()`
# 3. `df.describe()`
#
# Consider the following two questions:
#
# **Question 1:** When reviewing the `df.info()` output, what do you notice about the different variables? Are there any null values? Are all of the variables numeric? Does anything else stand out?
#
# **Question 2:** When reviewing the `df.describe()` output, what do you notice about the distributions of each variable? Are there any questionable values?

# %% [markdown]
# #Question 1:
# #No missing values: All 18 columns have 22,699 non-null entries, meaning the dataset is complete with no missing values.
# #Data types:
# #- 8 columns are of type float64 (e.g., fare_amount, total_amount).
# #- 7 columns are int64 (e.g., passenger_count, VendorID).
#  - 3 columns are object types:
# - tpep_pickup_datetime and tpep_dropoff_datetime should be converted to datetime type for time-based analysis.
# - store_and_fwd_flag should be converted to a categorical variable.
# Redundant column: 'Unnamed: 0' appears to be an unnecessary index column from the CSV export and should be dropped.
# Overall: The structure looks sound, but some type conversions are necessary for proper analysis.

# %%
df.head(10)
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# 5    23345809         2   03/25/2017 8:34:11 PM   03/25/2017 8:42:11 PM
# 6    37660487         2   05/03/2017 7:04:09 PM   05/03/2017 8:03:47 PM
# 7    69059411         2   08/15/2017 5:41:06 PM   08/15/2017 6:03:05 PM
# 8     8433159         2   02/04/2017 4:17:07 PM   02/04/2017 4:29:14 PM
# 9    95294817         1   11/10/2017 3:20:29 PM   11/10/2017 3:40:55 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %% [markdown]
# ### **Task 2c. Understand the data - Investigate the variables**
#
# Sort and interpret the data table for two variables:`trip_distance` and `total_amount`.
#
# **Answer the following three questions:**
#
# **Question 1:** Sort your first variable (`trip_distance`) from maximum to minimum value, do the values seem normal?
#
# **Question 2:** Sort by your second variable (`total_amount`), are any values unusual?
#
# **Question 3:** Are the resulting rows similar for both sorts? Why or why not?

# %% [markdown]
# ### Question 1:
# After sorting the `trip_distance` variable from maximum to minimum, the values seem normal. The highest values (e.g., 33.96 miles) are plausible for long taxi rides. The smallest values (e.g., 0) could indicate canceled trips or no-trip records, which will need further inspection.
#
# ### Question 2:
# The sorted `total_amount` variable shows some unusual values. While the highest fare amounts (up to $1200) might still be valid for long trips, the presence of negative values in `fare_amount` and `total_amount` (e.g., -120) should be flagged and investigated as data anomalies.
#
# ### Question 3:
# The rows for both sorts are somewhat similar in that higher `trip_distance` generally correlates with higher `total_amount`. However, the relationship is not perfectly linear because factors like tips, tolls, and surcharges affect the total fare.

# %%
df_sorted_trip_distance=df.sort_values(by='trip_distance',ascending=False)

print(df_sorted_trip_distance.head())
# Out:
#        Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 9280     51810714         2  06/18/2017 11:33:25 PM  06/19/2017 12:12:38 AM
# 13861    40523668         2   05/19/2017 8:20:21 AM   05/19/2017 9:20:30 AM
# 6064     49894023         2  06/13/2017 12:30:22 PM   06/13/2017 1:37:51 PM
# 10291    76319330         2  09/11/2017 11:41:04 AM  09/11/2017 12:18:58 PM
# 29       94052446         2   11/06/2017 8:30:50 PM  11/07/2017 12:00:00 AM
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 9280                 2          33.96           5                  N
# 13861                1          33.92           5                  N
# 6064                 1          32.72           3                  N
# 10291                1          31.95           4                  N
# 29                   1          30.83           1                  N
#
#        PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %%
df_sorted_total_amount=df.sort_values(by='total_amount',ascending=False)

print(df_sorted_total_amount.head(20))
# Out:
#        Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 8476     11157412         1   02/06/2017 5:50:10 AM   02/06/2017 5:51:08 AM
# 20312   107558404         2   12/19/2017 9:40:46 AM   12/19/2017 9:40:55 AM
# 13861    40523668         2   05/19/2017 8:20:21 AM   05/19/2017 9:20:30 AM
# 12511   107108848         2   12/17/2017 6:24:24 PM   12/17/2017 6:24:42 PM
# 15474    55538852         2   06/06/2017 8:55:01 PM   06/06/2017 8:55:06 PM
# 6064     49894023         2  06/13/2017 12:30:22 PM   06/13/2017 1:37:51 PM
# 16379   101198443         2  11/30/2017 10:41:11 AM  11/30/2017 11:31:45 AM
# 3582    111653084         1  01/01/2017 11:53:01 PM  01/01/2017 11:53:42 PM
# 11269    51920669         1  06/19/2017 12:51:17 AM  06/19/2017 12:52:12 AM
# 9280     51810714         2  06/18/2017 11:33:25 PM  06/19/2017 12:12:38 AM
# 1928     51087145         1   06/16/2017 6:30:08 PM   06/16/2017 7:18:50 PM
# ...

# %%
bottom_20=df.sort_values(by='total_amount',ascending=True).head(20)
bottom_20
# Out:
#        Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 12944    29059760         2  04/08/2017 12:00:16 AM  04/08/2017 11:15:57 PM
# 20698    14668209         2  02/24/2017 12:38:17 AM  02/24/2017 12:42:05 AM
# 17602    24690146         2   03/24/2017 7:31:13 PM   03/24/2017 7:34:49 PM
# 11204    58395501         2   07/09/2017 7:20:59 AM   07/09/2017 7:23:50 AM
# 14714   109276092         2  12/24/2017 10:37:58 PM  12/24/2017 10:41:08 PM
# 8204     91187947         2   10/28/2017 8:39:36 PM   10/28/2017 8:41:59 PM
# 20317    75926915         2  09/09/2017 10:59:51 PM  09/09/2017 11:02:06 PM
# 10281    55302347         2   06/05/2017 5:34:25 PM   06/05/2017 5:36:29 PM
# 5448     28459983         2  04/06/2017 12:50:26 PM  04/06/2017 12:52:39 PM
# 4423     97329905         2   11/16/2017 8:13:30 PM   11/16/2017 8:14:50 PM
# 18565    43859760         2   05/22/2017 3:51:20 PM   05/22/2017 3:52:22 PM
# ...

# %%
payment_map = {
    1: 'Credit card',
    2: 'Cash',
    3: 'No charge',
    4: 'Dispute',
    5: 'Unknown',
    6: 'Voided trip'
}
df['payment_type']=df['payment_type'].map(payment_map)
type_count=df['payment_type'].value_counts()
print(type_count)
# Out:
# Series([], Name: payment_type, dtype: int64)

# %% [markdown]
# According to the data dictionary, the payment method was encoded as follows:
#
# 1 = Credit card
# 2 = Cash
# 3 = No charge
# 4 = Dispute
# 5 = Unknown
# 6 = Voided trip

# %%
#==> ENTER YOUR CODE HERE

# What is the average tip for trips paid for with credit card?

# 1. Reload your CSV to restore the original state
df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')

# 2. Apply the mapping ONCE
payment_map = {
    1: 'Credit card',
    2: 'Cash',
    3: 'No charge',
    4: 'Dispute',
    5: 'Unknown',
    6: 'Voided trip'
}

df['payment_type'] = df['payment_type'].map(payment_map)

# 3. Confirm mapping worked
print(df['payment_type'].unique())

# 4. Compute average tip by payment method
avg_tip_cc = df[df['payment_type'] == 'Credit card']['tip_amount'].mean()

print(f"Average tip for credit card payments: ${avg_tip_cc:.2f}")


#==> ENTER YOUR CODE HERE

# What is the average tip for trips paid for with cash?
avg_tip_cash = df[df['payment_type'] == 'Cash']['tip_amount'].mean()
print(f"Average tip for cash payments: ${avg_tip_cash:.2f}")
# Out:
# ['Credit card' 'Cash' 'No charge' 'Dispute']
# Average tip for credit card payments: $2.73
# Average tip for cash payments: $0.00

# %%
#==> ENTER YOUR CODE HERE

# How many times is each vendor ID represented in the data?
vendor_ID_count=df['VendorID'].value_counts()
vendor_ID_count
# Out:
# 2    12626
# 1    10073
# Name: VendorID, dtype: int64

# %%
#==> ENTER YOUR CODE HERE

# What is the mean total amount for each vendor?


# Calculate the mean total amount for each VendorID and assign to a new column
df['mean_vendor'] = df.groupby('VendorID')['total_amount'].transform('mean')

# Display the DataFrame to check the result
print(df[['VendorID', 'total_amount', 'mean_vendor']])
# Out:
#        VendorID  total_amount  mean_vendor
# 0             2         16.56    16.320382
# 1             1         20.80    16.298119
# 2             1          8.75    16.298119
# 3             2         27.69    16.320382
# 4             2         17.80    16.320382
# ...         ...           ...          ...
# 22694         2          5.80    16.320382
# 22695         2         73.20    16.320382
# 22696         2          5.30    16.320382
# 22697         2         13.00    16.320382
# 22698         1         14.15    16.298119
#
# [22699 rows x 3 columns]

# %%
#==> ENTER YOUR CODE HERE

# Filter the data for credit card payments only
cc_payments=df[df['payment_type']=='Credit card']
cc_payments

#==> ENTER YOUR CODE HERE

# Filter the credit-card-only data for passenger count only

# Filter the credit-card-only data for passenger count only
cc_payments = df[df['payment_type'] == 'Credit card'][['payment_type', 'passenger_count']]

# Display the filtered data
print(cc_payments.head())
# Out:
#   payment_type  passenger_count
# 0  Credit card                6
# 1  Credit card                1
# 2  Credit card                1
# 3  Credit card                1
# 5  Credit card                6

# %%
#==> ENTER YOUR CODE HERE

# Calculate the average tip amount for each passenger count (credit card payments only)
cc_payment=df[df['payment_type']== 'Credit card']


mean_tip_paasnger_acount_cc=df.groupby('passenger_count')['tip_amount'].mean()

print(f"Average tip for credit card payments for each passenger count")
mean_tip_paasnger_acount_cc
# Out:
# Average tip for credit card payments for each passenger count
# passenger_count
# 0    2.135758
# 1    1.848920
# 2    1.856378
# 3    1.716768
# 4    1.530264
# 5    1.873185
# 6    1.720260
# Name: tip_amount, dtype: float64

# %% [markdown]
# <img src="images/Construct.png" width="100" height="100" align=left>
#
# ## PACE: **Construct**
#
# **Note**: The Construct stage does not apply to this workflow. The PACE framework can be adapted to fit the specific requirements of any project.

# %% [markdown]
# <img src="images/Execute.png" width="100" height="100" align=left>
#
# ## PACE: **Execute**
#
# Consider the questions in your PACE Strategy Document and those below to craft your response.

# %% [markdown]
# ### **Given your efforts, what can you summarize for DeShawn and the data team?**
#
# *Note for Learners: Your notebook should contain data that can address Luana's requests. Which two variables are most helpful for building a predictive model for the client: NYC TLC?*

# %% [markdown]
# ==> ENTER YOUR RESPONSE HERE
# # Summary for DeShawn and the Data Team
# Based on my analysis of the New York City Taxi & Limousine Commission (TLC) dataset, I have completed the initial data inspection and organization for future exploratory data analysis (EDA).
#
# Key Findings:
# 1. **Data Quality Issues**:
#    - Some suspicious values were detected, such as negative `fare_amount` and `total_amount`, as well as zero values in `trip_distance` and `passenger_count`, which may indicate canceled trips or data errors.
#    - Certain variables like `tpep_pickup_datetime` and `tpep_dropoff_datetime` need to be converted to datetime types for proper time-based analysis.
#    - Cleaning these anomalies will be important for ensuring accurate modeling.
#
# 2. **Key Variables for Predictive Modeling**:
#    - **`trip_distance`**: This variable is expected to be a significant predictor of the total fare amount, as longer trips generally result in higher fares. It's essential for modeling the impact of distance on fare generation.
#    - **`total_amount`**: This variable represents the total fare charged to passengers, including surcharges and tips. It is crucial for building models that predict taxi fares and customer payments.
#
# Next Steps:
# - Further investigate and clean suspicious data points, particularly those that involve negative or zero values.
# - Perform exploratory data analysis (EDA) to gain insights into the relationships between key variables such as `trip_distance`, `total_amount`, and `tip_amount`.
# - Prepare the data for predictive modeling, focusing on `trip_distance` and `total_amount` as the primary features for fare prediction.

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
